# %%
words = open('names.txt', 'r').read().splitlines()

# %%
words[:10]
# Out:
# ['emma',
#  'olivia',
#  'ava',
#  'isabella',
#  'sophia',
#  'charlotte',
#  'mia',
#  'amelia',
#  'harper',
#  'evelyn']

# %%
b = {}
for w in words[:10]:
  chs = ['<S>'] + list(w) + ['<E>']
  for ch1, ch2 in zip(chs, chs[1:]):
    #print(ch1, ch2)
    bigram = (ch1, ch2)
    b[bigram] = b.get(bigram, 0) + 1
print(b)
# Out:
# {('<S>', 'e'): 2, ('e', 'm'): 1, ('m', 'm'): 1, ('m', 'a'): 1, ('a', '<E>'): 7, ('<S>', 'o'): 1, ('o', 'l'): 1, ('l', 'i'): 2, ('i', 'v'): 1, ('v', 'i'): 1, ('i', 'a'): 4, ('<S>', 'a'): 2, ('a', 'v'): 1, ('v', 'a'): 1, ('<S>', 'i'): 1, ('i', 's'): 1, ('s', 'a'): 1, ('a', 'b'): 1, ('b', 'e'): 1, ('e', 'l'): 3, ('l', 'l'): 1, ('l', 'a'): 1, ('<S>', 's'): 1, ('s', 'o'): 1, ('o', 'p'): 1, ('p', 'h'): 1, ('h', 'i'): 1, ('<S>', 'c'): 1, ('c', 'h'): 1, ('h', 'a'): 2, ('a', 'r'): 2, ('r', 'l'): 1, ('l', 'o'): 1, ('o', 't'): 1, ('t', 't'): 1, ('t', 'e'): 1, ('e', '<E>'): 1, ('<S>', 'm'): 1, ('m', 'i'): 1, ('a', 'm'): 1, ('m', 'e'): 1, ('<S>', 'h'): 1, ('r', 'p'): 1, ('p', 'e'): 1, ('e', 'r'): 1, ('r', '<E>'): 1, ('e', 'v'): 1, ('v', 'e'): 1, ('l', 'y'): 1, ('y', 'n'): 1, ('n', '<E>'): 1}
